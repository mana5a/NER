# %%
import spacy 
from spacy import displacy
from collections import Counter 
import en_core_web_sm
nlp=en_core_web_sm.load()
import pandas as pd 
file=pd.read_csv('placement.csv',skiprows=[0,-1],usecols=[2,3])
df=pd.DataFrame(file)

# %%
df
#doc=nlp('Interest in fuzzy systems was sparked by Seiji Yasunobu and Soji Miyamoto of Hitachi, who in 1985 provided simulations that demonstrated the feasibility of fuzzy control systems for the Sendai Subway')
# Out:
#                                 What is your question?  \
# 0             What was the stipend for Morgan Stanley?
# 1    What subjects do I generally focus on to prepa...
# 2    When will companies be arriving for campus pla...
# 3                 How many companies above 20CTC come?
# 4                  How many companies have a clear JD?
# 5        What is the policy regarding dream companies?
# 6           How are the off campus taken into account?
# 7                         How much value does it hold?
# 8    How many rounds of interviews are conducted us...
# 9    Are there any companies that publish annual CT...
# 10   How many companies visit for 3rd year internsh...
# 11                               Where should I do it?
# 12                          How much does Intuit pay?
# 13            Should I register for all the companies?
# 14                   How much does Morgan Stanley pay?
# 15                                    Does pay matter?
# 16        List the companies that have a service bond.
# 17                           How much does Citrix pay?
# 18   Is it better to try to get an internship or to...
# 19                   How much does Goldman Sachs pay?
# 20   Do any companies with high (12+) base pay come...
# 21   How likely is it that internship will convert ...
# 22                   When do placements usually begin?
# 23                                  Are interns paid?
# 24               what are the tier 1, 2 and 3 cutoffs?
# 25               how many offers can you hold at once?
# 26   Does it make sense to move to Bellandur for th...
# 27   Is it better to do a research based internship...
# 28                   Do companies have a CGPA Cut-off?
# 29   Does 24l package mean that I'll be getting 24 ...
# ..                                                 ...
# 96   Is there a bunch of FAQs available for everyon...
# 97   Do we get to choose the company we intern for ...
# 98                                  Placement process?
# 99   What kind of internships and projects do i hav...
# 100  What are the most important topics for placeme...
# 101  What are the necessary topics I have to be pro...
# 102       How to study data structures for placements?
# 103                Can I skip the Pre placement talks?
# 104       What platform is the coding test usually on?
# 105  What types of questions are there in a coding ...
# 106                          Is 1st year CGPA counted?
# 107  Do companies usually allow it's 3rd year summe...
# 108  How can it be useful to intern if you have alr...
# 109               How many students get Tier 1 offers?
# 110   How many research companies come for placements?
# 111               What's the importance of GATE score?
# 112           Is internship compulsory for placement ?
# 113          Does college offer any summer internships
# 114            What is the cutoff cgpa for placements?
# 115  Are the projects done as a part of the course ...
# 116  Any clue as to what to do if the placements st...
# 117  which are the startups that are doing well and...
# 118  What are the job titles offered and which job ...
# 119          Which company has a good working culture?
# 120  Is a Research Project for credits helpful to d...
# 121  How do companies grade internships for 8th sem...
# 122  Placement now and masters later or the opposit...
# 123           Will we have any pre placement training?
# 124                                                NaN
# 125                                                NaN
#
#                                              Answer-1
# 0                                      87000 per month
# 1                            DS Algo OS and basic DBMS
# 2    Morgan Stanley came on Oct 1 for the class of ...
# 3    There isn't a definite number of companies. Bu...
# 4    Most companies have to fill out a job form whe...
# 5    They've introduced a Super Dream category for ...
# 6    3rd year internships aren't completely necassa...
# 7    3rd semester internships at industries might l...
# 8    most companies have around 2 rounds of technic...
# 9    Companies usually amortize the cost they incur...
# 10   Can't really say. They come throught the year,...
# 11   Depends on your preference. Can be at an indus...
# 12                     Base: 13,50,000, CTC: 25,16,750
# 13   Placement Cell has restrictions on applying to...
# 14   Fixed Pay : 13,00,000  Total Compensation Year...
# 15                        Depends on your preference.
# 16   T1 companies don't usually have service bonds....
# 17              Base Pay : 115000 Total CTC : 23.42lpa
# 18   Depends on your preference, getting a PPO migh...
# 19   Total Compensation: 22 lpa; CTC: 16lpa; One ti...
# 20   Quite a few of them do come even after August,...
# 21   Depends on the company. Each company has a dif...
# 22                             3rd or 4th week of July
# 23   Companies rarely don't offer stipends. Minimum...
# 24   tier 1 : 8L CTC and above; tier 2: 4-8L CTC; t...
# 25   Once you have an offer in a tier, you can only...
# 26   Depends on where you live, the timings of your...
# 27   There's no wrong answer. Depends on your prefe...
# 28              Yes, usually 7, 8, 8.5. Rarely above 9
# 29   The CTC package that companies give is usually...
# ..                                                 ...
# 96   There isn't yet. That's the idea behind this f...
# 97   You get to choose the company you apply to bas...
# 98                                      What about it?
# 99                                        Check Row 30
# 100  Check Row 4 and 54. They won't check your cert...
# 101                                Check Row 4 and 54.
# 102                          Suggestion: Geeksforgeeks
# 103  They usually try to make sure you don't miss t...
# 104               HackerRank, Hacker Earth, Amcat etc.
# 105  Mostly Technical or Aptitude MCQs, Fix the cod...
# 106  CGPA(Cummulative Grade point average) is cummu...
# 107  Internships usually get over before the drive ...
# 108  It's personal choice. If you're satisfied with...
# 109                      Statistics change every year.
# 110  Companies like Samsung R&D and LamReasearch co...
# 111  No one really asks for it as far as I know. Co...
# 112                               Redundant question.
# 113  There are clubs in college where you could wor...
# 114                               Redundant question.
# 115  Everyone would have done projects in the same ...
# 116  You'll have to give up the first few weeks of ...
# 117                                                NaN
# 118  Each company has different titles and roles. T...
# 119                                                NaN
# 120  During 8th sem you have 2 options. To do a maj...
# 121  For the class of 2020, the department has spec...
# 122  Depends on your preference. The notion is that...
# 123                                Redundant question.
# 124                                                NaN
# 125
#
# [126 rows x 2 columns]

# %%
# df.columns.values
# df['answer']

# %%
# print(df.iloc[0][0])
# print(df.iloc[0][1])

# %%
data=[]
for i in range (0, len(df)):
    obj=dict()
    obj['question']=str(df['question'][i])
    obj['answer']=str(df['answer'][i])
    data.append(obj)
# print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'question'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-4a05615f2580> in <module>
#       2 for i in range (0, len(df)):
#       3     obj=dict()
# ----> 4     obj['question']=str(df['question'][i])
#       5     obj['answer']=str(df['answer'][i])
#       6     data.append(obj)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'question'

# %%
# data
len(data)

# %%
for i in range(0, len(data)):
    doc = nlp(data[i]['question'])
    for ent in doc.ents: 
        print(ent.text, ent.start_char, ent.end_char, ent.label_)
